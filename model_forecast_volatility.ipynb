# %%
pip install arch

# %%
from arch import arch_model
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from datetime import datetime, timedelta

# %%
start = datetime(2005,3,1)
end = datetime(2021,1,12)

# %%
df = pd.read_excel('BSE_NSE_returns.xlsx')
df.head()
# Out:
#         Date   Sensex  SensexReturns    Nifty  NiftyReturns
# 0 2005-01-03  6679.20            NaN  2115.00           NaN
# 1 2005-01-04  6651.01      -0.183685  2103.75     -0.231624
# 2 2005-01-05  6458.84      -1.273307  2032.20     -1.502768
# 3 2005-01-06  6367.39      -0.619308  1998.35     -0.729489
# 4 2005-01-07  6420.46       0.360469  2015.50      0.371125

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4))
plt.plot(df.SensexReturns)

# %%
plt.figure(figsize=(10,4))
plt.plot(df.NiftyReturns)

# %%
df.set_index('Date',inplace=True)

# %%
plot_pacf(df.SensexReturns)
plt.show()

# %%
df.dropna(inplace=True)
model = arch_model(df.SensexReturns,p=1,q=1)
model_fit = model.fit()
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 2930.355560335777
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 2927.659646338424
# Iteration:      3,   Func. Count:     25,   Neg. LLF: 2926.1438253238957
# Iteration:      4,   Func. Count:     32,   Neg. LLF: 2925.5811483395555
# Iteration:      5,   Func. Count:     39,   Neg. LLF: 2919.8289935967487
# Iteration:      6,   Func. Count:     47,   Neg. LLF: 2918.7441869570666
# Iteration:      7,   Func. Count:     54,   Neg. LLF: 2916.0731162302054
# Iteration:      8,   Func. Count:     61,   Neg. LLF: 2915.9500143094137
# Iteration:      9,   Func. Count:     68,   Neg. LLF: 2915.917476081117
# Iteration:     10,   Func. Count:     75,   Neg. LLF: 2915.8231434797203
# Iteration:     11,   Func. Count:     81,   Neg. LLF: 2915.7620134802655
# Iteration:     12,   Func. Count:     87,   Neg. LLF: 2915.7614516897347
# Iteration:     13,   Func. Count:     93,   Neg. LLF: 2915.761443691962
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2915.7614436871536
#             Iterations: 13
#             Function evaluations: 93
#             Gradient evaluations: 13

# %%
df.dropna(inplace=True)
model1 = arch_model(df.NiftyReturns,p=1,q=1)
model_fit1 = model1.fit()
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 2967.571470602611
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 2965.0987274148247
# Iteration:      3,   Func. Count:     26,   Neg. LLF: 2962.9793794414813
# Iteration:      4,   Func. Count:     33,   Neg. LLF: 2957.746268806226
# Iteration:      5,   Func. Count:     40,   Neg. LLF: 2956.9207915781462
# Iteration:      6,   Func. Count:     47,   Neg. LLF: 2955.9372307341237
# Iteration:      7,   Func. Count:     54,   Neg. LLF: 2954.883864370998
# Iteration:      8,   Func. Count:     61,   Neg. LLF: 2954.538868727898
# Iteration:      9,   Func. Count:     70,   Neg. LLF: 2954.533008299637
# Iteration:     10,   Func. Count:     76,   Neg. LLF: 2954.417834093374
# Iteration:     11,   Func. Count:     82,   Neg. LLF: 2954.389447645536
# Iteration:     12,   Func. Count:     88,   Neg. LLF: 2954.389193176761
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2954.3891926867836
#             Iterations: 12
#             Function evaluations: 89
#             Gradient evaluations: 12

# %%
model_fit1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:           NiftyReturns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -2954.39
# Distribution:                  Normal   AIC:                           5916.78
# Method:            Maximum Likelihood   BIC:                           5942.14
#                                         No. Observations:                 4194
# Date:                Mon, Dec 06 2021   Df Residuals:                     4193
# Time:                        14:18:35   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0358  6.909e-03      5.179  2.227e-07 [2.224e-02,4.933e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      3.7523e-03  1.089e-03      3.447  5.669e-04 [1.619e-03,5.886e-03]
# alpha[1]       0.0984  1.276e-02      7.713  1.232e-14   [7.339e-02,  0.123]
# beta[1]        0.8933  1.255e-02     71.159      0.000     [  0.869,  0.918]
# ============================================================================
#
# Covariance estimator: robust
# """

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:          SensexReturns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -2915.76
# Distribution:                  Normal   AIC:                           5839.52
# Method:            Maximum Likelihood   BIC:                           5864.89
#                                         No. Observations:                 4194
# Date:                Mon, Dec 06 2021   Df Residuals:                     4193
# Time:                        14:12:18   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0371  6.846e-03      5.421  5.910e-08 [2.370e-02,5.054e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      3.6328e-03  1.014e-03      3.582  3.408e-04 [1.645e-03,5.620e-03]
# alpha[1]       0.0956  1.228e-02      7.782  7.126e-15   [7.151e-02,  0.120]
# beta[1]        0.8956  1.232e-02     72.686      0.000     [  0.871,  0.920]
# ============================================================================
#
# Covariance estimator: robust
# """

# %%
df.SensexReturns[:-365]
# Out:
# Date
# 2005-01-04   -0.183685
# 2005-01-05   -1.273307
# 2005-01-06   -0.619308
# 2005-01-07    0.360469
# 2005-01-10   -0.763728
#                 ...
# 2020-06-10    0.369782
# 2020-06-11   -0.908122
# 2020-06-12    0.312914
# 2020-06-15   -0.715643
# 2020-06-16    0.489209
# Name: SensexReturns, Length: 3829, dtype: float64

# %%
rolling_predictions1 = []
test_size = 365

for i in range(test_size):
    train1 = df.NiftyReturns
    model1 = arch_model(train1, p=1, q=1)
    model_fit1 = model1.fit(disp='off')
    pred1 = model_fit1.forecast(horizon=1)
    rolling_predictions1.append(np.sqrt(pred1.variance.values[-1,:][0]))

# %%
rolling_predictions1 = pd.Series(rolling_predictions1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4))
preds, = plt.plot(rolling_predictions1)
plt.title('Volatility Prediction - Rolling Forecast', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Volatility Prediction - Rolling Forecast')

# %%
rolling_predictions1 = []
test_size = 365

for i in range(test_size):
    train1 = df.NiftyReturns[:-(test_size-i)]
    model1 = arch_model(train1, p=1, q=1)
    model_fit1 = model1.fit(disp='off')
    pred1 = model_fit1.forecast(horizon=1)
    rolling_predictions1.append(np.sqrt(pred1.variance.values[-1,:][0]))

# %%
rolling_predictions1 = pd.Series(rolling_predictions1, index=df.NiftyReturns.index[-test_size:])

# %%
rolling_predictions = []
test_size = 365

for i in range(test_size):
    train = df.SensexReturns[:-(test_size-i)]
    model = arch_model(train, p=1, q=1)
    model_fit = model.fit(disp='off')
    pred = model_fit.forecast(horizon=1)
    rolling_predictions.append(np.sqrt(pred.variance.values[-1,:][0]))

# %%
rolling_predictions = pd.Series(rolling_predictions, index=df.SensexReturns.index[-test_size:])

# %%
rolling_predictions
# Out:
# Date
# 2020-06-17    0.667744
# 2020-06-18    0.635665
# 2020-06-19    0.662309
# 2020-06-22    0.658839
# 2020-06-23    0.628330
#                 ...
# 2021-11-25    0.415357
# 2021-11-26    0.408268
# 2021-11-29    0.562264
# 2021-11-30    0.535676
# 2021-12-01    0.513488
# Length: 365, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4))
true, = plt.plot(df.SensexReturns[-test_size:])
preds, = plt.plot(rolling_predictions)
plt.title('Volatility Prediction - Rolling Forecast', fontsize=20)
plt.legend(['True Returns', 'Predicted Volatility'], fontsize=16)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4))
true, = plt.plot(df.NiftyReturns[-test_size:])
preds, = plt.plot(rolling_predictions1)
plt.title('Volatility Prediction - Rolling Forecast', fontsize=20)
plt.legend(['True Returns', 'Predicted Volatility'], fontsize=16)

# %%
df.NiftyReturns[:-(730)]
# Out:
# Date
# 2005-01-04   -0.231624
# 2005-01-05   -1.502768
# 2005-01-06   -0.729489
# 2005-01-07    0.371125
# 2005-01-10   -0.727915
#                 ...
# 2018-12-13    0.217661
# 2018-12-14    0.055903
# 2018-12-17    0.331921
# 2018-12-18    0.081093
# 2018-12-19    0.232672
# Name: NiftyReturns, Length: 3464, dtype: float64

# %%
df.SensexReturns[-730:-480]
# Out:
# Date
# 2018-12-20   -0.062730
# 2018-12-21   -0.829938
# 2018-12-24   -0.331668
# 2018-12-26    0.219578
# 2018-12-27    0.191253
#                 ...
# 2019-12-20    0.007940
# 2019-12-23   -0.040529
# 2019-12-24   -0.189597
# 2019-12-26   -0.312746
# 2019-12-27    0.431868
# Name: SensexReturns, Length: 250, dtype: float64

# %%
rolling_predictions1 = []
test_size = 250

for i in range(test_size):
    train1 = df.NiftyReturns[:-(test_size-i)]
    model1 = arch_model(train1, p=1, q=1)
    model_fit1 = model1.fit(disp='off')
    pred1 = model_fit1.forecast(horizon=1)
    rolling_predictions1.append(np.sqrt(pred1.variance.values[-1,:][0]))

# %%
rolling_predictions1 = pd.Series(rolling_predictions1, index=df.NiftyReturns.index[-730:-480])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4))
true, = plt.plot(df.NiftyReturns[-730:-480])
preds, = plt.plot(rolling_predictions1)
plt.title('Volatility Prediction - Rolling Forecast', fontsize=20)
plt.legend(['True Returns', 'Predicted Volatility'], fontsize=16)

# %%
rolling_predictions1 = []
test_size = 250

for i in range(test_size):
    train1 = df.SensexReturns[:-(730-i)]
    model1 = arch_model(train1, p=1, q=1)
    model_fit1 = model1.fit(disp='off')
    pred1 = model_fit1.forecast(horizon=1)
    rolling_predictions1.append(np.sqrt(pred1.variance.values[-1,:][0]))

# %%
df.SensexReturns[:-(730)]
# Out:
# Date
# 2005-01-04   -0.183685
# 2005-01-05   -1.273307
# 2005-01-06   -0.619308
# 2005-01-07    0.360469
# 2005-01-10   -0.763728
#                 ...
# 2018-12-13    0.182382
# 2018-12-14    0.040220
# 2018-12-17    0.369333
# 2018-12-18    0.092113
# 2018-12-19    0.163685
# Name: SensexReturns, Length: 3464, dtype: float64

# %%
rolling_predictions1 = pd.Series(rolling_predictions1, index=df.SensexReturns.index[-730:-480])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4))
true, = plt.plot(df.SensexReturns[-730:-480])
preds, = plt.plot(rolling_predictions1)
plt.title('Volatility Prediction - Rolling Forecast', fontsize=20)
plt.legend(['True Returns', 'Predicted Volatility'], fontsize=16)

# %%
df.SensexReturns[-730:-480]
# Out:
# Date
# 2018-12-20   -0.062730
# 2018-12-21   -0.829938
# 2018-12-24   -0.331668
# 2018-12-26    0.219578
# 2018-12-27    0.191253
#                 ...
# 2019-12-20    0.007940
# 2019-12-23   -0.040529
# 2019-12-24   -0.189597
# 2019-12-26   -0.312746
# 2019-12-27    0.431868
# Name: SensexReturns, Length: 250, dtype: float64

# %%
rolling_predictions1 = []
test_size = 250

for i in range(test_size):
    train1 = df.NiftyReturns[:-(730-i)]
    model1 = arch_model(train1, p=1, q=1)
    model_fit1 = model1.fit(disp='off')
    pred1 = model_fit1.forecast(horizon=1)
    rolling_predictions1.append(np.sqrt(pred1.variance.values[-1,:][0]))

# %%
rolling_predictions1 = pd.Series(rolling_predictions1, index=df.NiftyReturns.index[-730:-480])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4))
true, = plt.plot(df.NiftyReturns[-730:-480])
preds, = plt.plot(rolling_predictions1)
plt.title('Volatility Prediction - Rolling Forecast', fontsize=20)
plt.legend(['True Returns', 'Predicted Volatility'], fontsize=16)
